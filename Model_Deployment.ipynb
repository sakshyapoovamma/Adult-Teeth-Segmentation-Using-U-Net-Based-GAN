# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
cd gdrive/MyDrive/Colab Notebooks/Dental_dataset/Adult tooth segmentation dataset/Panoramic radiography database
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/DentalDataset

# %%
import tensorflow as tf
from keras import models
G = tf.keras.models.load_model('./final_tooth_mask_generation.h5')

# %%
img = cv2.imread("teeth.png", 0)
img = img/255
img = cv2.resize(img, (224, 224))

# %%
plt.imshow(img, cmap = 'gray')

# %%
image = np.array(img)

# %%
image.shape
# Out:
# (224, 224)

# %%
image = image.reshape((1, 224, 224, 1))
mask_pred = G.predict(image)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
plt.imshow(np.reshape(mask_pred, (224, 224)), cmap = 'gray')
